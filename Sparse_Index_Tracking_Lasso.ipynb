# %%
import numpy as np
import cvxpy as cp
import matplotlib.pyplot as plt
import pandas as pd
import yfinance as yf
import matplotlib

from skglm import GeneralizedLinearEstimator
from skglm.penalties import L1
from skglm.datafits import Quadratic,Huber
from utils import comp_sharpe_ratio, comp_sortion_ratio, comp_MDD, comp_calmar_ratio

matplotlib.rcParams.update({'font.size': 16})

# %%
company_table = pd.read_html('https://en.wikipedia.org/wiki/Nasdaq-100')[4]
stock_list = company_table['Ticker'].to_list()

# %%
start_time = '2017-01-01'
end_time = '2022-12-31'

stock_data = []
for idx in stock_list:
    temp_data = yf.download(idx, start=start_time, end=end_time)
    data_ = pd.DataFrame()
    data_[idx] = temp_data['Adj Close']
    stock_data.append(data_)

stock_data = pd.concat(stock_data, axis=1)
stock_data = stock_data.reset_index()
stock_data['Date'] = pd.to_datetime(stock_data['Date'], format="%d-%m-%Y").dt.date
stock_data = stock_data.set_index('Date')

stock_data = stock_data.fillna(method='ffill')
stock_data = stock_data.fillna(method='bfill')

stock_pct = stock_data.pct_change()[1:]
stock_idx = stock_pct.index
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
nasdaq_data =  yf.download('^NDX', start=start_time, end=end_time)['Adj Close']

nasdaq_data = nasdaq_data.fillna(method='ffill')
nasdaq_data = nasdaq_data.fillna(method='bfill')

nasdaq_pct = nasdaq_data.pct_change()[1:]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
train_widnow = 100
test_window = 30

X = stock_pct.values * 100
y = nasdaq_pct.values * 100

T = X.shape[0]
y_est_dict = {}

y_gt_list = []
y_est_list = []
alphas = [i for i in np.arange(0.01, 0.1, 0.01)]

for idx, alpha in enumerate(alphas):
    alpha = round(alpha, 3)
    model = GeneralizedLinearEstimator(Quadratic(), L1(alpha=alpha, positive=True))
    
    for i in range(train_widnow, T - test_window, test_window):
        X_train = X[i - train_widnow:i, :]
        y_train = y[i - train_widnow:i]

        X_test = X[i:i + test_window, :]
        y_test = y[i:i + test_window]

        model.fit(X_train, y_train)
        w_est = model.coef_
        w_est = w_est / np.sum(w_est)
        y_est = X_test.dot(w_est)

        y_est_list.append(y_est)
        y_gt_list.append(y_test)
        
    y_res = np.concatenate(y_est_list)
    y_gt = np.concatenate(y_gt_list)
    
    y_est_dict[alpha] = y_res
    
    y_est_list = [] 
    y_gt_list = []

# %%
plt.figure(figsize=(15, 8))
indx = stock_idx[train_widnow + test_window-1:]
plt.plot(indx, np.cumprod(1 + y_gt/100), '--', color='black', label = 'Index(Nasdaq-100)')

for key, val in y_est_dict.items():
    plt.plot(indx, np.cumprod(1 + val/100), label='alpha=' + str(key))
plt.ylabel("Cumulative return")
plt.xlabel("Date")
plt.title("The cumulative return with compound of LASSO and Benchmark")
plt.legend(bbox_to_anchor=(1.00, 1.0), loc='upper left')
plt.show()

# %%
def comp_measures(X, N=256, rf=0.00):
    
    sharpe_ratio = comp_sharpe_ratio(X, N, rf)
    sortion_ratio = comp_sortion_ratio(X, N, rf)
    maxDD, maxDDD, i = comp_MDD(X)
    calmer_ratio = comp_calmar_ratio(X)

    print("sharpe ratio is {:.4f}, sortion ratio is {:.4f}, the calmer ratio is {:.4f}".format(sharpe_ratio, 
                                                                                               sortion_ratio, 
                                                                                               calmer_ratio)) 
    print("the maximum drawdown is {:.4f}, the duration of maximum drawdown is {:.4f}\n".format(maxDD, maxDDD))

# %%
for key, val in y_est_dict.items():
    print("the parameter:", key)
    comp_measures(val/100)
# Out:
# the parameter: 0.01
# sharpe ratio is 0.7225, sortion ratio is 0.9167, the calmer ratio is 0.7038
# the maximum drawdown is -0.2716, the duration of maximum drawdown is 226.0000
#
# the parameter: 0.02
# sharpe ratio is 0.7266, sortion ratio is 0.9264, the calmer ratio is 0.7099
# the maximum drawdown is -0.2755, the duration of maximum drawdown is 226.0000
#
# the parameter: 0.03
# sharpe ratio is 0.7247, sortion ratio is 0.9266, the calmer ratio is 0.7123
# the maximum drawdown is -0.2775, the duration of maximum drawdown is 226.0000
#
# the parameter: 0.04
# sharpe ratio is 0.7266, sortion ratio is 0.9319, the calmer ratio is 0.7179
# the maximum drawdown is -0.2792, the duration of maximum drawdown is 226.0000
#
# the parameter: 0.05
# sharpe ratio is 0.7285, sortion ratio is 0.9368, the calmer ratio is 0.7233
# the maximum drawdown is -0.2807, the duration of maximum drawdown is 226.0000
#
# the parameter: 0.06
# sharpe ratio is 0.7272, sortion ratio is 0.9372, the calmer ratio is 0.7228
# the maximum drawdown is -0.2831, the duration of maximum drawdown is 226.0000
#
# the parameter: 0.07
# sharpe ratio is 0.7252, sortion ratio is 0.9360, the calmer ratio is 0.7218
# the maximum drawdown is -0.2854, the duration of maximum drawdown is 226.0000
#
# the parameter: 0.08
# sharpe ratio is 0.7257, sortion ratio is 0.9377, the calmer ratio is 0.7247
# the maximum drawdown is -0.2871, the duration of maximum drawdown is 226.0000
#
# the parameter: 0.09
# sharpe ratio is 0.7263, sortion ratio is 0.9389, the calmer ratio is 0.7290
# the maximum drawdown is -0.2881, the duration of maximum drawdown is 226.0000

# %%
train_widnow = 100
test_window = 30

X = stock_pct.values * 100
y = nasdaq_pct.values * 100

T = X.shape[0]
y_est_dict_huber = {}

y_gt_list = []
y_est_list = []
alphas = [i for i in np.arange(0.01, 0.1, 0.01)]

for idx, alpha in enumerate(alphas):
    alpha = round(alpha, 3)
    model = GeneralizedLinearEstimator(Huber(delta=0.1), L1(alpha=alpha, positive=True))
    
    for i in range(train_widnow, T - test_window, test_window):
        X_train = X[i - train_widnow:i, :]
        y_train = y[i - train_widnow:i]

        X_test = X[i:i + test_window, :]
        y_test = y[i:i + test_window]

        model.fit(X_train, y_train)
        w_est = model.coef_
        w_est = w_est / np.sum(w_est)
        y_est = X_test.dot(w_est)

        y_est_list.append(y_est)
        y_gt_list.append(y_test)
        
    y_res = np.concatenate(y_est_list)
    y_gt = np.concatenate(y_gt_list)
    
    y_est_dict_huber[alpha] = y_res
    
    y_est_list = [] 
    y_gt_list = []

# %%
plt.figure(figsize=(15, 8))
indx = stock_idx[train_widnow + test_window-1:]
plt.plot(indx, np.cumprod(1 + y_gt/100), '--', color='black', label = 'Index(Nasdaq-100)')

for key, val in y_est_dict_huber.items():
    plt.plot(indx, np.cumprod(1 + val/100), label='alpha=' + str(key))
plt.ylabel("Cumulative return")
plt.xlabel("Date")
plt.title("The cumulative return with compound of LASSO(Huber loss) and Benchmark")
plt.legend(bbox_to_anchor=(1.00, 1.0), loc='upper left')
plt.show()

# %%
for key, val in y_est_dict.items():
    print("the parameter:", key)
    comp_measures(val/100)
# Out:
# the parameter: 0.01
# sharpe ratio is 0.7225, sortion ratio is 0.9167, the calmer ratio is 0.7038
# the maximum drawdown is -0.2716, the duration of maximum drawdown is 226.0000
#
# the parameter: 0.02
# sharpe ratio is 0.7266, sortion ratio is 0.9264, the calmer ratio is 0.7099
# the maximum drawdown is -0.2755, the duration of maximum drawdown is 226.0000
#
# the parameter: 0.03
# sharpe ratio is 0.7247, sortion ratio is 0.9266, the calmer ratio is 0.7123
# the maximum drawdown is -0.2775, the duration of maximum drawdown is 226.0000
#
# the parameter: 0.04
# sharpe ratio is 0.7266, sortion ratio is 0.9319, the calmer ratio is 0.7179
# the maximum drawdown is -0.2792, the duration of maximum drawdown is 226.0000
#
# the parameter: 0.05
# sharpe ratio is 0.7285, sortion ratio is 0.9368, the calmer ratio is 0.7233
# the maximum drawdown is -0.2807, the duration of maximum drawdown is 226.0000
#
# the parameter: 0.06
# sharpe ratio is 0.7272, sortion ratio is 0.9372, the calmer ratio is 0.7228
# the maximum drawdown is -0.2831, the duration of maximum drawdown is 226.0000
#
# the parameter: 0.07
# sharpe ratio is 0.7252, sortion ratio is 0.9360, the calmer ratio is 0.7218
# the maximum drawdown is -0.2854, the duration of maximum drawdown is 226.0000
#
# the parameter: 0.08
# sharpe ratio is 0.7257, sortion ratio is 0.9377, the calmer ratio is 0.7247
# the maximum drawdown is -0.2871, the duration of maximum drawdown is 226.0000
#
# the parameter: 0.09
# sharpe ratio is 0.7263, sortion ratio is 0.9389, the calmer ratio is 0.7290
# the maximum drawdown is -0.2881, the duration of maximum drawdown is 226.0000
